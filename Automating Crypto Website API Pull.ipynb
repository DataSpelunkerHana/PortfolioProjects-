# %%
#This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'b54bcf4d-1bca-4e8e-9a24-22ff2c3d462c',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2023-04-24T14:50:22.439Z', 'error_code': 0, 'error_message': None, 'elapsed': 1, 'credit_count': 1, 'notice': None}, 'data': [{'id': 1862, 'name': '4vm7ff3ukok', 'symbol': 'o9e1zhnh25l', 'slug': 'ahgnwgvrri', 'cmc_rank': 9209, 'num_market_pairs': 3330, 'circulating_supply': 7244, 'total_supply': 3872, 'max_supply': 6808, 'infinite_supply': None, 'last_updated': '2023-04-24T14:50:22.439Z', 'date_added': '2023-04-24T14:50:22.439Z', 'tags': ['s7d770fpmj', 'ojin0pba9ap', 'xkv6qoik2yc', '24j8c1499agh', 'oa9st4h3w5', 'a0knftcgc1r', 'ivw0hyzqad', '4m906sqgd6o', 'ibctmm9wyll', '3m54dn7yt4'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.9374428337747109, 'volume_24h': 2525, 'volume_change_24h': 0.05421455332264791, 'percent_change_1h': 0.045363220791230674, 'percent_change_24h': 0.5731822944980951, 'percent_change_7d': 0.8431226382787254, 'market_cap': 0.252344968705964, 'market_cap_dominan
# ...

# %%
#This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'afa0ec93-3583-4f11-9e34-f3fefb7cf29c',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)


#NOTE: Go in and put "jupyter notebook --NotebookApp.iopub_data_rate_limit=1.0e10"
# Into the Anaconda Prompt to change this to allow to pull data

# If that didn't work try using the local host URL as shown in the video
# Out:
# {'status': {'timestamp': '2023-04-24T14:50:24.933Z', 'error_code': 0, 'error_message': None, 'elapsed': 17, 'credit_count': 1, 'notice': None, 'total_count': 9335}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10185, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'pa
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
pd.json_normalize(data['status'])
# Out:
#                   timestamp  error_code error_message  elapsed  credit_count  \
# 0  2023-04-24T14:50:24.933Z           0          None       17             1
#
#   notice  total_count
# 0   None         9335

# %%
df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now', utc = True)
df
# Out:
#       id         name symbol          slug  num_market_pairs  \
# 0      1      Bitcoin    BTC       bitcoin             10185
# 1   1027     Ethereum    ETH      ethereum              6774
# 2    825       Tether   USDT        tether             51793
# 3   1839          BNB    BNB           bnb              1278
# 4   3408     USD Coin   USDC      usd-coin             11998
# 5     52          XRP    XRP           xrp               936
# 6   2010      Cardano    ADA       cardano               767
# 7     74     Dogecoin   DOGE      dogecoin               694
# 8   3890      Polygon  MATIC       polygon               669
# 9   5426       Solana    SOL        solana               457
# 10  6636     Polkadot    DOT  polkadot-new               498
# 11  4687  Binance USD   BUSD   binance-usd              6649
# 12     2     Litecoin    LTC      litecoin               906
# 13  5994    Shiba Inu   SHIB     shiba-inu               508
# ...

# %%
def api_runner():

    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
     'start':'1',
     'limit':'15',
     'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': 'afa0ec93-3583-4f11-9e34-f3fefb7cf29c',
    }

    session = Session()
    session.headers.update(headers)

    try:
        response = session.get(url, params=parameters)
        data = json.loads(response.text)
        #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
        print(e)
    

    
    df2 = pd.json_normalize(data['data'])
    df2['timestamp'] = pd.to_datetime('now', utc = True)
    df = df.append(df2)
    
    
    
      # Use this if you want to create a csv and append data to it
    
     #df = pd.json_normalize(data['data'])
     #df['timestamp'] = pd.to_datetime('now', utc = True)
     #df 

     #if not os.path.isfile(r'C:\Users\hanak\Exercises\Portfolio Project\Python Scripts\APInew.csv'):
       # df.to_csv(r'C:\Users\hanak\Exercises\Portfolio Project\Python Scripts\APInew.csv', header='column_names')
     #else:
       #  df.to_csv(r'C:\Users\hanak\Exercises\Portfolio Project\Python Scripts\APInew.csv', mode='a', header = False)
    
    
    
    #The timestamp column is added into the dataframe and the current time is displayed.
    
    
    
     # Use this code if you just want to keep it just in a dataframe 
        
    # df2 = pd.json_normalize(data['data'])
    # df2['timestamp'] = pd.to_datetime('now' , utc = True)
    # df = df.append(df2)

# %%
import os
from time import time
from time import sleep


for i in range(333):   #'333' is the max no of times this api can be called per day.
    api_runner()
    print('API runner completed successfully!')
    sleep(60)        # Sleeps for 60 seconds
exit()
# Out:
# C:\Users\hanak\AppData\Local\Temp\ipykernel_1216\3520453923.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)
# API runner completed successfully!
# C:\Users\hanak\AppData\Local\Temp\ipykernel_1216\3520453923.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)
# API runner completed successfully!
# C:\Users\hanak\AppData\Local\Temp\ipykernel_1216\3520453923.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)
# API runner completed successfully!
# C:\Users\hanak\AppData\Local\Temp\ipykernel_1216\3520453923.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
df97 = pd.read_csv(r'C:\Users\hanak\Exercises\Portfolio Project\Python Scripts\APInew.csv')
df97
# Out:
#     Unnamed: 0    id         name symbol          slug  num_market_pairs  \
# 0            0     1      Bitcoin    BTC       bitcoin             10171
# 1            1  1027     Ethereum    ETH      ethereum              6749
# 2            2   825       Tether   USDT        tether             51599
# 3            3  1839          BNB    BNB           bnb              1272
# 4            4  3408     USD Coin   USDC      usd-coin             11924
# 5            5    52          XRP    XRP           xrp               936
# 6            6  2010      Cardano    ADA       cardano               767
# 7            7    74     Dogecoin   DOGE      dogecoin               692
# 8            8  3890      Polygon  MATIC       polygon               663
# 9            9  5426       Solana    SOL        solana               456
# 10          10  6636     Polkadot    DOT  polkadot-new               498
# 11          11  4687  Binance USD   BUSD   binance-usd              6634
# ...

# %%
df
# Out:
#       id         name symbol          slug  num_market_pairs  \
# 0      1      Bitcoin    BTC       bitcoin             10185
# 1   1027     Ethereum    ETH      ethereum              6774
# 2    825       Tether   USDT        tether             51793
# 3   1839          BNB    BNB           bnb              1278
# 4   3408     USD Coin   USDC      usd-coin             11998
# 5     52          XRP    XRP           xrp               936
# 6   2010      Cardano    ADA       cardano               767
# 7     74     Dogecoin   DOGE      dogecoin               694
# 8   3890      Polygon  MATIC       polygon               669
# 9   5426       Solana    SOL        solana               457
# 10  6636     Polkadot    DOT  polkadot-new               498
# 11  4687  Binance USD   BUSD   binance-usd              6649
# 12     2     Litecoin    LTC      litecoin               906
# 13  5994    Shiba Inu   SHIB     shiba-inu               508
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df
# Out:
#       id         name symbol          slug  num_market_pairs  \
# 0      1      Bitcoin    BTC       bitcoin             10185
# 1   1027     Ethereum    ETH      ethereum              6774
# 2    825       Tether   USDT        tether             51793
# 3   1839          BNB    BNB           bnb              1278
# 4   3408     USD Coin   USDC      usd-coin             11998
# 5     52          XRP    XRP           xrp               936
# 6   2010      Cardano    ADA       cardano               767
# 7     74     Dogecoin   DOGE      dogecoin               694
# 8   3890      Polygon  MATIC       polygon               669
# 9   5426       Solana    SOL        solana               457
# 10  6636     Polkadot    DOT  polkadot-new               498
# 11  4687  Binance USD   BUSD   binance-usd              6649
# 12     2     Litecoin    LTC      litecoin               906
# 13  5994    Shiba Inu   SHIB     shiba-inu               508
# ...

# %%
df3 = df.groupby('name', sort = False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#              quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                         -0.91480                      -0.59975
# Ethereum                        -0.73927                      -0.69239
# Tether                           0.02466                      -0.00204
# BNB                             -0.42032                       0.27832
# USD Coin                         0.01503                       0.00956
# XRP                             -1.07364                      -1.37975
# Cardano                         -0.93323                       0.27665
# Dogecoin                        -0.90883                      -1.02503
# Polygon                         -1.14090                      -1.84237
# Solana                          -1.45481                      -1.10457
# Polkadot                        -1.08730                      -0.16480
# Binance USD                      0.00243                       0.00703
# ...

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin      quote.USD.percent_change_1h     -0.91480
#              quote.USD.percent_change_24h    -0.59975
#              quote.USD.percent_change_7d     -6.87446
#              quote.USD.percent_change_30d    -0.61553
#              quote.USD.percent_change_60d    13.99515
#              quote.USD.percent_change_90d    19.56029
# Ethereum     quote.USD.percent_change_1h     -0.73927
#              quote.USD.percent_change_24h    -0.69239
#              quote.USD.percent_change_7d    -10.72937
#              quote.USD.percent_change_30d     5.77706
#              quote.USD.percent_change_60d    11.48461
#              quote.USD.percent_change_90d    14.44922
# Tether       quote.USD.percent_change_1h      0.02466
#              quote.USD.percent_change_24h    -0.00204
#              quote.USD.percent_change_7d     -0.00241
#              quote.USD.percent_change_30d    -0.06333
#              quote.USD.percent_change_60d     0.00921
# ...

# %%
type(df3)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
#Changing the df4 from pandas series to a dataframe.

df5 = df4.to_frame(name='values')
df5
# Out:
#                                             values
# name
# Bitcoin     quote.USD.percent_change_1h   -0.91480
#             quote.USD.percent_change_24h  -0.59975
#             quote.USD.percent_change_7d   -6.87446
#             quote.USD.percent_change_30d  -0.61553
#             quote.USD.percent_change_60d  13.99515
#             quote.USD.percent_change_90d  19.56029
# Ethereum    quote.USD.percent_change_1h   -0.73927
#             quote.USD.percent_change_24h  -0.69239
#             quote.USD.percent_change_7d  -10.72937
#             quote.USD.percent_change_30d   5.77706
#             quote.USD.percent_change_60d  11.48461
#             quote.USD.percent_change_90d  14.44922
# Tether      quote.USD.percent_change_1h    0.02466
#             quote.USD.percent_change_24h  -0.00204
#             quote.USD.percent_change_7d   -0.00241
#             quote.USD.percent_change_30d  -0.06333
#             quote.USD.percent_change_60d   0.00921
# ...

# %%
type(df5)
# Out:
# pandas.core.frame.DataFrame

# %%
df5.count()
# Out:
# values    90
# dtype: int64

# %%
# Indexing the values using numbers instead of name.

index = pd.Index(range(90))

#df6 = df5.set_index(index)
df6 = df5.reset_index()
df6
# Out:
#            name                       level_1    values
# 0       Bitcoin   quote.USD.percent_change_1h  -0.91480
# 1       Bitcoin  quote.USD.percent_change_24h  -0.59975
# 2       Bitcoin   quote.USD.percent_change_7d  -6.87446
# 3       Bitcoin  quote.USD.percent_change_30d  -0.61553
# 4       Bitcoin  quote.USD.percent_change_60d  13.99515
# 5       Bitcoin  quote.USD.percent_change_90d  19.56029
# 6      Ethereum   quote.USD.percent_change_1h  -0.73927
# 7      Ethereum  quote.USD.percent_change_24h  -0.69239
# 8      Ethereum   quote.USD.percent_change_7d -10.72937
# 9      Ethereum  quote.USD.percent_change_30d   5.77706
# 10     Ethereum  quote.USD.percent_change_60d  11.48461
# 11     Ethereum  quote.USD.percent_change_90d  14.44922
# 12       Tether   quote.USD.percent_change_1h   0.02466
# 13       Tether  quote.USD.percent_change_24h  -0.00204
# 14       Tether   quote.USD.percent_change_7d  -0.00241
# 15       Tether  quote.USD.percent_change_30d  -0.06333
# ...

# %%
df7 = df6.rename(columns={'level_1':'percent_change'})
df7
# Out:
#            name                percent_change    values
# 0       Bitcoin   quote.USD.percent_change_1h  -0.91480
# 1       Bitcoin  quote.USD.percent_change_24h  -0.59975
# 2       Bitcoin   quote.USD.percent_change_7d  -6.87446
# 3       Bitcoin  quote.USD.percent_change_30d  -0.61553
# 4       Bitcoin  quote.USD.percent_change_60d  13.99515
# 5       Bitcoin  quote.USD.percent_change_90d  19.56029
# 6      Ethereum   quote.USD.percent_change_1h  -0.73927
# 7      Ethereum  quote.USD.percent_change_24h  -0.69239
# 8      Ethereum   quote.USD.percent_change_7d -10.72937
# 9      Ethereum  quote.USD.percent_change_30d   5.77706
# 10     Ethereum  quote.USD.percent_change_60d  11.48461
# 11     Ethereum  quote.USD.percent_change_90d  14.44922
# 12       Tether   quote.USD.percent_change_1h   0.02466
# 13       Tether  quote.USD.percent_change_24h  -0.00204
# 14       Tether   quote.USD.percent_change_7d  -0.00241
# 15       Tether  quote.USD.percent_change_30d  -0.06333
# ...

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['1h','24h','7d','30d','60d','90d'])
df7
# Out:
#            name percent_change    values
# 0       Bitcoin             1h  -0.91480
# 1       Bitcoin            24h  -0.59975
# 2       Bitcoin             7d  -6.87446
# 3       Bitcoin            30d  -0.61553
# 4       Bitcoin            60d  13.99515
# 5       Bitcoin            90d  19.56029
# 6      Ethereum             1h  -0.73927
# 7      Ethereum            24h  -0.69239
# 8      Ethereum             7d -10.72937
# 9      Ethereum            30d   5.77706
# 10     Ethereum            60d  11.48461
# 11     Ethereum            90d  14.44922
# 12       Tether             1h   0.02466
# 13       Tether            24h  -0.00204
# 14       Tether             7d  -0.00241
# 15       Tether            30d  -0.06333
# 16       Tether            60d   0.00921
# 17       Tether            90d   0.01091
# 18          BNB             1h  -0.42032
# 19          BNB            24h   0.27832
# 20          BNB             7d  -2.37938
# 21          BNB            30d   2.35238
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y='values', hue='name', data = df7, kind = 'point')

# %%
df8 = df[['name','quote.USD.price','timestamp']]
df8 = df8.query("name == 'Bitcoin'")
df8
# Out:
#        name  quote.USD.price                        timestamp
# 0   Bitcoin      27351.28577 2023-04-24 14:50:25.110685+00:00
# 15  Bitcoin      27401.45381 2023-04-24 14:56:22.363857+00:00
# 30  Bitcoin      27388.89809 2023-04-24 14:57:23.851007+00:00
# 45  Bitcoin      27388.89809 2023-04-24 14:58:25.266847+00:00
# 60  Bitcoin      27431.00960 2023-04-24 14:59:27.199232+00:00
# 75  Bitcoin      27410.57012 2023-04-24 15:00:28.846807+00:00
# 90  Bitcoin      27427.83854 2023-04-24 15:01:30.486508+00:00

# %%
sns.set_theme(style='darkgrid')

sns.lineplot(x='timestamp', y='quote.USD.price', data=df8)
# Out:
# <AxesSubplot:xlabel='timestamp', ylabel='quote.USD.price'>
